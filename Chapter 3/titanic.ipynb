# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %%
train = pd.read_csv("titanic_train.csv")
test = pd.read_csv("titanic_test.csv")

train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
display(train[train.Age.isnull()])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
train_notnull = train.iloc[:,[1,2,4,6,7,9]].dropna()
test_notnull = test.iloc[:,[1,3,5,6,8,10]].dropna()
display(train_notnull)
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare
# 0           0       3    male      1      0   7.2500
# 1           1       1  female      1      0  71.2833
# 2           1       3  female      0      0   7.9250
# 3           1       1  female      1      0  53.1000
# 4           0       3    male      0      0   8.0500
# ..        ...     ...     ...    ...    ...      ...
# 886         0       2    male      0      0  13.0000
# 887         1       1  female      0      0  30.0000
# 888         0       3  female      1      2  23.4500
# 889         1       1    male      0      0  30.0000
# 890         0       3    male      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
train_notnull.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
y_age_train = train.Age[train.Age.notnull() & train.Embarked.notnull()].values
X_age_train = train[train.Age.notnull() & train.Embarked.notnull()].drop(['PassengerId','Name','Ticket','Age','Cabin','Embarked'], axis=1)
X_age_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   SibSp     712 non-null    int64
#  4   Parch     712 non-null    int64
#  5   Fare      712 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 38.9+ KB

# %%
X_age_train_cat = X_age_train.Sex.values
X_age_train_num = X_age_train.drop(['Sex'], axis=1)
len(X_age_train_cat)
# Out:
# 712

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
num_pipeline = Pipeline([
        ('std_scaler', StandardScaler()),
])
display(X_age_train_num)
# Out:
#      Survived  Pclass  SibSp  Parch     Fare
# 0           0       3      1      0   7.2500
# 1           1       1      1      0  71.2833
# 2           1       3      0      0   7.9250
# 3           1       1      1      0  53.1000
# 4           0       3      0      0   8.0500
# ..        ...     ...    ...    ...      ...
# 885         0       3      0      5  29.1250
# 886         0       2      0      0  13.0000
# 887         1       1      0      0  30.0000
# 889         1       1      0      0  30.0000
# 890         0       3      0      0   7.7500
#
# [712 rows x 5 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
num_attribs = list(X_age_train_num)
cat_attribs = ["Sex"]
full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", OneHotEncoder(), cat_attribs),
])
X_age_train_prepared = full_pipeline.fit_transform(X_age_train)

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X_age_train_prepared,y_age_train)
age_pre = forest_reg.predict(X_age_train_prepared)

# %%
from sklearn.model_selection import cross_val_score
print(np.sqrt(- cross_val_score(forest_reg,X_age_train_prepared,y_age_train,
                             scoring="neg_mean_squared_error",cv=10)))
# Out:
# [11.91231646 12.04436278 11.88604046 12.47929379 12.62365712 14.53888415
#  13.42645834 13.09625032 14.00109776 13.92606328]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{'n_estimators': np.arange(1, 200, 1).tolist(),
               'criterion': ["mse", "mae"]
              }]

grid_search = GridSearchCV(forest_reg, param_grid, cv=5, verbose=3)
grid_search.fit(X_age_train_prepared, y_age_train)
# Out:
# Fitting 5 folds for each of 398 candidates, totalling 1990 fits
# [CV] criterion=mse, n_estimators=1 ...................................
# [CV] ....... criterion=mse, n_estimators=1, score=0.104, total=   0.0s
# [CV] criterion=mse, n_estimators=1 ...................................
# [CV] ...... criterion=mse, n_estimators=1, score=-0.082, total=   0.0s
# [CV] criterion=mse, n_estimators=1 ...................................
# [CV] ...... criterion=mse, n_estimators=1, score=-0.084, total=   0.0s
# [CV] criterion=mse, n_estimators=1 ...................................
# [CV] ...... criterion=mse, n_estimators=1, score=-0.264, total=   0.0s
# [CV] criterion=mse, n_estimators=1 ...................................
# [CV] ...... criterion=mse, n_estimators=1, score=-0.279, total=   0.0s
# [CV] criterion=mse, n_estimators=2 ...................................
# [CV] ....... criterion=mse, n_estimators=2, score=0.174, total=   0.0s
# ...

# %%
forest_reg = grid_search.best_estimator_
forest_reg.fit(X_age_train_prepared,y_age_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mae',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=42, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print(np.sqrt(- cross_val_score(forest_reg,X_age_train_prepared,y_age_train,

                             scoring="neg_mean_squared_error",cv=10)))
# Out:
# [12.01597138 12.36042494 11.47049521 12.63372056 12.11264618 14.2070118
#  13.29900412 13.46053719 13.69104106 13.03216437]

# %%
# Out:
# [12.05768979 12.14905934 13.29428965 13.4093011  14.36640331]
